# %%
import rapid_code_load_T0 as load
import formation_channels as fc

# %% [markdown]
# ###  all of the data stored in the simulated_binary_populations folder in the Drive should be T0 and loadable as follows
#
# ### Don't edit this notebook!

# %%
path = 'data/T0_format_pilot/COSMIC/basic/COSMIC_T0.hdf5'

# %%
COSMIC_T0, COSMIC_header = load.load_T0_data(path)
ZAMS, WDMS, DWD = fc.select_evolutionary_states(d=COSMIC_T0)

# %%
ZAMS
# Out:
#             ID     UID  time  event    semiMajor  eccentricity  type1  \
# 0            0       0   0.0   13.0     5.285510           0.0  121.0
# 1            1       1   0.0   13.0     5.623710           0.0  121.0
# 2            2       2   0.0   13.0     5.983551           0.0  121.0
# 3            3       3   0.0   13.0     6.366416           0.0  121.0
# 4            4       4   0.0   13.0     6.773779           0.0  121.0
# ...        ...     ...   ...    ...          ...           ...    ...
# 477094  477094  477094   0.0   13.0  4371.595046           0.0  121.0
# 477095  477095  477095   0.0   13.0  4651.317141           0.0  121.0
# 477096  477096  477096   0.0   13.0  4948.937613           0.0  121.0
# 477097  477097  477097   0.0   13.0  5265.601710           0.0  121.0
# 477098  477098  477098   0.0   13.0  5602.527964           0.0  121.0
#
#             mass1   radius1         Teff1  massHeCore1  type2      mass2  \
# ...

# %%
WDMS.semiMajor
# Out:
# 0           1.179356
# 1           1.269760
# 2           1.366523
# 3           1.470905
# 4           1.584176
#              ...
# 208227    223.673710
# 208228    225.587020
# 208229    229.521108
# 208230    234.922798
# 208231    239.392874
# Name: semiMajor, Length: 208232, dtype: float64
